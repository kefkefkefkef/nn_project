# %% [markdown]
# <a href="https://colab.research.google.com/github/IlvirH/nn_project/blob/main/ImageNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torchvision
import torch.nn as nn
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision import transforms as T
from torchvision import io
# !pip install torchutils
import torchutils as tu
import json
import numpy as np
import matplotlib.pyplot as plt
import os
device = 'cuda' if torch.cuda.is_available() else 'cpu'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import torch
from torchvision import models, transforms
from PIL import Image
import urllib.request
import json

# Загрузка предобученной модели Inception
model = models.inception_v3(pretrained=True)
model.eval()

# Загрузка файла с метками классов ImageNet
LABELS_URL = 'https://raw.githubusercontent.com/anishathalye/imagenet-simple-labels/master/imagenet-simple-labels.json'
labels_path = 'imagenet_labels.json'
urllib.request.urlretrieve(LABELS_URL, labels_path)

# Загрузка меток классов
with open(labels_path) as f:
    labels = json.load(f)

# Предобработка изображения
preprocess = transforms.Compose([
    transforms.Resize(299),
    transforms.CenterCrop(299),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Загрузка и классификация изображения
def classify_image(image_path):
    image = Image.open(image_path)
    image = preprocess(image)
    image = image.unsqueeze(0)  # добавляем размерность пакета

    # Передача изображения через модель
    with torch.no_grad():
        output = model(image)

    # Получение предсказаний классов
    _, predicted_idx = torch.max(output, 1)
    predicted_label = labels[predicted_idx.item()]
    return predicted_label


# !wget -O image2.jpg https://old.bigenc.ru/media/2016/10/27/1235209875/19116.jpg.262x-.png

image_path = 'image2.jpg'
predicted_class = classify_image(image_path)

resize = T.Resize((224, 224))
img = resize(io.read_image('image2.jpg')/255)
img = resize(io.read_image('image2.jpg')/255)
model.to(device)
model.eval()
plt.imshow(torch.permute(img, (1, 2, 0)))
plt.title(predicted_class);
# Out:
# --2023-05-26 14:08:58--  https://old.bigenc.ru/media/2016/10/27/1235209875/19116.jpg.262x-.png
# Resolving old.bigenc.ru (old.bigenc.ru)... 149.126.168.169
# Connecting to old.bigenc.ru (old.bigenc.ru)|149.126.168.169|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 58209 (57K) [image/jpeg]
# Saving to: ‘image2.jpg’
#
# image2.jpg          100%[===================>]  56.84K  --.-KB/s    in 0.1s
#
# 2023-05-26 14:08:59 (451 KB/s) - ‘image2.jpg’ saved [58209/58209]

# %%
# !wget -O image2.jpg https://cdn.iportal.ru/preview/news/articles/77ae8cfdc64b9922ddc0222250f811630d92e867_1280_854.jpg

image_path = 'image2.jpg'
predicted_class = classify_image(image_path)

resize = T.Resize((224, 224))
img = resize(io.read_image('image2.jpg')/255)
img = resize(io.read_image('image2.jpg')/255)
model.to(device)
model.eval()
plt.imshow(torch.permute(img, (1, 2, 0)))
plt.title(predicted_class);
# Out:
# --2023-05-26 14:10:46--  https://cdn.iportal.ru/preview/news/articles/77ae8cfdc64b9922ddc0222250f811630d92e867_1280_854.jpg
# Resolving cdn.iportal.ru (cdn.iportal.ru)... 185.40.155.13
# Connecting to cdn.iportal.ru (cdn.iportal.ru)|185.40.155.13|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 310534 (303K) [image/jpeg]
# Saving to: ‘image2.jpg’
#
# image2.jpg          100%[===================>] 303.26K  1020KB/s    in 0.3s
#
# 2023-05-26 14:10:47 (1020 KB/s) - ‘image2.jpg’ saved [310534/310534]

# %%
# !wget -O image2.jpg https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQYx7oPkYfSdxalNu55l-kem9YnHXhBbKirfg&usqp=CAU
image_path = 'image2.jpg'
predicted_class = classify_image(image_path)

resize = T.Resize((224, 224))
img = resize(io.read_image('image2.jpg')/255)
img = resize(io.read_image('image2.jpg')/255)
model.to(device)
model.eval()
plt.imshow(torch.permute(img, (1, 2, 0)))
plt.title(predicted_class);
# Out:
# --2023-05-26 14:11:54--  https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQYx7oPkYfSdxalNu55l-kem9YnHXhBbKirfg
# Resolving encrypted-tbn0.gstatic.com (encrypted-tbn0.gstatic.com)... 172.217.204.138, 172.217.204.100, 172.217.204.102, ...
# Connecting to encrypted-tbn0.gstatic.com (encrypted-tbn0.gstatic.com)|172.217.204.138|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9268 (9.1K) [image/jpeg]
# Saving to: ‘image2.jpg’
#
# image2.jpg          100%[===================>]   9.05K  --.-KB/s    in 0s
#
# 2023-05-26 14:11:54 (82.3 MB/s) - ‘image2.jpg’ saved [9268/9268]

# %%
# !wget -O image2.jpg https://web-zoopark.ru/wp-content/uploads/2018/06/7-132-735x400.jpg
image_path = 'image2.jpg'
predicted_class = classify_image(image_path)

resize = T.Resize((224, 224))
img = resize(io.read_image('image2.jpg')/255)
img = resize(io.read_image('image2.jpg')/255)
model.to(device)
model.eval()
plt.imshow(torch.permute(img, (1, 2, 0)))
plt.title(predicted_class);
# Out:
# --2023-05-26 14:12:41--  https://web-zoopark.ru/wp-content/uploads/2018/06/7-132-735x400.jpg
# Resolving web-zoopark.ru (web-zoopark.ru)... 92.53.96.137
# Connecting to web-zoopark.ru (web-zoopark.ru)|92.53.96.137|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 52432 (51K) [image/jpeg]
# Saving to: ‘image2.jpg’
#
# image2.jpg          100%[===================>]  51.20K  --.-KB/s    in 0.1s
#
# 2023-05-26 14:12:43 (411 KB/s) - ‘image2.jpg’ saved [52432/52432]
